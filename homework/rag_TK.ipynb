# %% [markdown]
# # Retrieval Augmented Generation (RAG)

# %% [markdown]
# We can think of large language models (LLMs) as people who have read every book in a library up until a certain date. 📚 They've remembered the content with varying degrees of accuracy, but their knowledge base consists of everything that was in that library.
#
# In the case of LLMs, the "library" is actually a massive collection of internet documents—heavily filtered for quality—along with some curated private datasets, such as newspaper archives and academic papers.
#
# If we need the model to understand or use information that was not (or only barely) included in its training data, we have to provide that information in the prompt. However, there's a limit to how much information we can give at once. This is due to something called a context window—a maximum number of tokens (e.g., 8,096 tokens) that the model can process in a single prompt.

# %% [markdown]
# ## Augmented

# %%
from ollama import chat
from IPython.display import Markdown, display

chat_response = chat(model='gemma3:1b', messages=[
    {
    'role': 'user',
    'content': 'Hey, I am looking for some gifts, could you recommend some',
    },
])

display(Markdown(chat_response.message.content))
# Out:
# Okay, let’s brainstorm some gift ideas! To give you the *best* recommendations, I need a little more information about you and what you’re looking for. But, here’s a breakdown of ideas categorized by budget and interests, covering a wide range of possibilities:
#
# **1. Quick & Easy (Under $30)**
#
# * **Coffee/Tea Sampler:** A curated selection of unique coffees or teas is always a nice treat.
# * **Scented Candle:** Choose a scent you love – floral, citrus, woodsy, etc.
# * **Small Plant (Succulent or Air Plant):** A low-maintenance plant is a lovely addition to any space.
# * **Cozy Socks or Slippers:** Perfect for chilly days.
# * **Bath Bombs or Bubble Bath:** A little relaxation!
# * **Mug with a Funny Quote:**  A little dose of humor.
#
#
# **2. $30 - $75**
#
# * **Book:**  Based on their interests (mystery, romance, biography, etc.).  Consider a popular new release or a classic.
# * **Board Game or Card Game:**  Great for game nights.
# * **Adult Coloring Book & Colored Pencils:**  A relaxing and creative activity.
# * **Small Kitchen Gadget:**  A garlic press, avocado slicer, or a nice whisk.
# * **Gift Card to a Favorite Store:**  (Amazon, Target, Starbucks, etc.) - lets them choose what they want.
# * **Subscription Box (Trial):** There are subscription boxes for almost every interest (beauty, snacks, books, etc.)
#
#
# **3. $75 - $150**
#
# * **Experiences:** Tickets to a concert, play, or sporting event.
# * **Jewelry:** A simple necklace or bracelet. (Consider their style!)
# * **Tech Accessory:** Wireless earbuds, a portable charger, a stylish phone stand.
# * **Home Decor Item:**  A decorative pillow, a small canvas art print, a succulent planter.
# * **High-Quality Journal & Pen Set:** For creative writing or note-taking.
# * **Small Electronics Accessory:** A cool bluetooth speaker, a portable projector.
#
#
# **4. $150+ (Consider these based on their interests):**
#
# * **Clothing/Accessories:**  Based on their style preferences.
# * **For the Hobbyist:**  If they have a specific hobby (photography, knitting, woodworking), a related gift.
# * **High-Quality Coffee Maker/Espresso Machine:**  If they’re a coffee lover.
# * **Personalized Gift:** A mug, necklace, or bracelet with their initials or a special date.
# * **Subscription to a Streaming Service (Netflix, Spotify, etc.)**
#
#
# **To help me narrow it down and give you even *better* recommendations, could you tell me:**
#
# *   **Who are you buying for?** (e.g., boyfriend, girlfriend, mother, friend, coworker?)
# *   **What are their interests/hobbies?** (e.g., reading, hiking, cooking, gaming, music, art, gardening?)
# *   **What's your budget?** (A range is fine – e.g., $25-$50, $50-$100, $100+)
# *   **What's their personality like?** (e.g., practical, sentimental, adventurous, quirky?)

# %% [markdown]
# ---

# %% [markdown]
# Let's now do the same with the context that it is currently Easter and see how the model adapts its gift recommendations.

# %%
extra_content = "It is the First of Mai 2026."

chat_response = chat(model='gemma3:1b', messages=[
    {
    'role': 'user',
    'content': 'Hey, I am looking for some gifts, could you recommend some' + extra_content,
    },
])

display(Markdown(chat_response.message.content))
# Out:
# Okay, let's brainstorm some gift ideas for the First of Mai 2026! That's a really beautiful time of year – it's a celebration of the arrival of spring and renewal. Here’s a breakdown of ideas, broken down by budget and interest, categorized for easier browsing:
#
# **1. Budget-Friendly & Thoughtful ($20 - $50)**
#
# * **Small Plant:** A succulent, air plant, or a small potted herb like rosemary or basil. They’re easy to care for and add a touch of life.
# * **Floral Arrangement:** A small, beautiful floral arrangement – even a single, striking bunch of flowers is lovely.
# * **Tea & Treats Basket:**  A selection of her favorite teas, artisanal chocolates, and maybe a cute mug.
# * **Handmade Soap or Candle:**  A lovely, handcrafted soap or scented candle can be a comforting and beautiful gift.
# * **Small Decorative Item:** A charming ceramic mug, a set of small watercolor paintings, or a unique wooden ornament.
#
#
# **2. Mid-Range ($50 - $150)**
#
# * **Experiences:** Tickets to a local event (farmers market, concert, outdoor movie), a workshop (pottery, floral arranging), or a spa treatment.
# * **Cozy Blanket or Throw:**  A plush, warm blanket is perfect for chilly spring evenings.
# * **Book:**  Choose a book by a favorite author or in a genre they enjoy (mystery, romance, biography, etc.).
# * **Beautiful Journal & Pen Set:** If they enjoy writing, a nice journal and a quality pen can be a great gift.
# * **Small Artisan Food Basket:**  Think cheeses, crackers, jams, and other gourmet treats.
# * **Something related to Spring Flowers:**  A beautiful vase to display her favorite blooms, a set of gardening tools, or a book about spring flowers.
#
#
#
# **3.  More Luxurious & Personalized ($150+)**
#
# * **Jewelry:**  A simple necklace, bracelet, or earrings.
# * **Gift Certificate:** To their favorite store or a place they'd enjoy.
# * **Personalized Keepsake:**  A framed photo, a piece of artwork with their name, or a custom-made item.
# * **High-Quality Tea Set:**  A beautiful set of porcelain or ceramic tea cups and a nice selection of loose-leaf teas.
# * **Subscription Box:**  There are subscription boxes tailored to specific interests (coffee, books, beauty products, etc.)
# * **Beautiful Scarf or Accessory:** If they love fashion, a stylish scarf or a unique handbag accessory would be lovely.
#
#
#
# **To help me narrow it down and give you even *better* recommendations, could you tell me a little more about the person you're shopping for?**
#
# *   **What are their interests/hobbies?** (e.g., gardening, reading, cooking, travel, art, music, etc.)
# *   **What's their personality like?** (e.g.,  practical, sentimental, adventurous, minimalist, etc.)
# *   **What's your budget?** (A general range is fine - e.g., under $50, $50-$100, $100+)
# *   **Do they prefer practical gifts, sentimental gifts, or experiences?**

# %% [markdown]
# ---

# %% [markdown]
# The notebook is named **RAG (Retrieval-Augmented Generation)**. In this context, "augmentation" refers to enriching the generation process with additional, task-specific information. However, when the volume of available data is too large to insert in full, we must **retrieve** only the most relevant parts to use as context.
#
# **Note**: Having a context window of for example 128.000 tokens does not mean that we should fill it up until that. Adding more and more tokens leads to more latency (i.e. it takes longer for the model to serve the user) and there could be also an information overload i.e. that the information fits into the context window but there is just too much information for the model may overlook important details. (This in the end could be only found out by testing, but personally I think in terms of information density and complexity. The german "Bild Zeitung" has for example a very low information density and complexity while a medical textbook has a very high information density and complexity. Hence doing Q&A over 30.000 tokens of Bild articles is definitively not the same as doing Q&A over 30.000 tokens of medical textbook pages.

# %% [markdown]
# ## Retrieval

# %% [markdown]
# For actually retrieving something we need data. Let us consider for now this simplified database of ten different entries/documents about talks given on a future festival. We want to build a small RAG chatbot for festival visitors where they can ask for their specific interests what talks would fits the most.
#
# **Note** The dataset is so small that I would personally just completly put it always in the context but for demonstration purposes let's use the talks as single documents. Read through them to get a grasp of the data below:

# %% [markdown]
# ##### 1. 🌿 **The Next Nature: Designing with the Future in Mind**
# *Explore how biomimicry, regenerative design, and synthetic biology are reshaping architecture, materials, and cities. Where does design end and nature begin?*
#
# ---
#
# ##### 2. 🧠 **Neural Frontiers: The Brain-Computer Interface Revolution**
# *From thought-controlled devices to memory enhancement, dive into the fast-evolving world of brain tech — and the ethical mazes it brings.*
#
# ---
#
# ##### 3. 🎨🤖 **AI & the Soul of Art: Who Really Owns Creativity?**
# *Artists, coders, and philosophers debate the rise of generative art. Can machines make meaning? And where does human intuition still reign supreme?*
#
# ---
#
# ##### 4. 💼🚫 **Post-Work: Imagining a Life Beyond Jobs**
# *As automation reshapes labor, what comes next? UBI, digital nomadism, reputation economies — a candid discussion about freedom, purpose, and survival.*
#
# ---
#
# ##### 5. 🪐 **Planet B: Terraforming Ideas for Earth 2.0**
# *Science fiction meets climate urgency. This talk blends real research with wild speculation — from Mars domes to floating cities in the clouds of Venus.*
#
# ---
#
# ##### 6. 🕶️🌐 **Reality is Optional: The Rise of Immersive Worlds**
# *VR, AR, XR — and whatever’s next. What happens when our digital spaces feel more real than reality itself? And who gets to write the rules?*
#
# ---
#
# ##### 7. 🧬⏳ **The Ethics of Immortality: Living Forever in a Mortal World**
# *Cryonics, gene editing, mind uploading — tech is chasing eternal life. But what would it mean for love, loss, and the human condition?*
#
# ---
#
# ##### 8. 💻⚖️ **Code as Culture: Programming the Future We Want**
# *Code is not neutral — it shapes societies. This talk explores how developers are becoming the new lawmakers, and how we hold them accountable.*
#
# ---
#
# ##### 9. 🕸️🛠️ **The Wild Web: Reclaiming the Internet from Algorithms**
# *Can we rebuild the web for people, not profit? Meet the rebels, hackers, and dreamers creating decentralized, community-first digital spaces.*
#
# ---
#
# ##### 10. 🕰️🚀 **Time Travelers Welcome: Building the Long Now**
# *Futurists, historians, and deep-time thinkers gather to explore projects that think in centuries — from 10,000-year clocks to interstellar archives.*

# %% [markdown]
# ---

# %% [markdown]
# Okay, we see depending on your interests there might different talks to be the most interesting ones.
#
# First we need to prepare the talks

# %%
festival_talks = [
    "🌿 The Next Nature: Designing with the Future in Mind — Explore how biomimicry, regenerative design, and synthetic biology are reshaping architecture, materials, and cities. Where does design end and nature begin?",
    "🧠 Neural Frontiers: The Brain-Computer Interface Revolution — From thought-controlled devices to memory enhancement, dive into the fast-evolving world of brain tech — and the ethical mazes it brings.",
    "🎨🤖 AI & the Soul of Art: Who Really Owns Creativity? — Artists, coders, and philosophers debate the rise of generative art. Can machines make meaning? And where does human intuition still reign supreme?",
    "💼🚫 Post-Work: Imagining a Life Beyond Jobs — As automation reshapes labor, what comes next? UBI, digital nomadism, reputation economies — a candid discussion about freedom, purpose, and survival.",
    "🪐 Planet B: Terraforming Ideas for Earth 2.0 — Science fiction meets climate urgency. This talk blends real research with wild speculation — from Mars domes to floating cities in the clouds of Venus.",
    "🕶️🌐 Reality is Optional: The Rise of Immersive Worlds — VR, AR, XR — and whatever’s next. What happens when our digital spaces feel more real than reality itself? And who gets to write the rules?",
    "🧬⏳ The Ethics of Immortality: Living Forever in a Mortal World — Cryonics, gene editing, mind uploading — tech is chasing eternal life. But what would it mean for love, loss, and the human condition?",
    "💻⚖️ Code as Culture: Programming the Future We Want — Code is not neutral — it shapes societies. This talk explores how developers are becoming the new lawmakers, and how we hold them accountable.",
    "🕸️🛠️ The Wild Web: Reclaiming the Internet from Algorithms — Can we rebuild the web for people, not profit? Meet the rebels, hackers, and dreamers creating decentralized, community-first digital spaces.",
    "🕰️🚀 Time Travelers Welcome: Building the Long Now — Futurists, historians, and deep-time thinkers gather to explore projects that think in centuries — from 10,000-year clocks to interstellar archives."
]

# %% [markdown]
# For the retrieval part we need a kind of search based on the question over talks. The standard way was to do a key word search but with the upcoming AI era that default changed to a vector search. Therefor we need another type of model: An embedding model. An embedding model takes a text and transforms it into a vector of a certain size (e.g. 1*1048). Every text is mapped to a the same vector size. The embedding models are pretrained that they map similar texts close to each other in the vector space (so LLMs aren't the only cool models). Luckily ollama and also all major providers like openai and huggingface also provide embedding models. We will now take the currently best embedding models from ollama (lukily the embedding models are usually really small < 1GB)
#
# Run **ollama pull nomic-embed-text** in your terminal
#
# Ollama is able to serve the LLM and the embedding model at the same time (given enough (V)RAM)

# %%
from ollama import embed

# Generate an embedding for a single input
response = embed(model='nomic-embed-text', input='opencampus is the best!')

# Access the embedding vector
embedding = response['embeddings']
print(embedding)
print(len(embedding[0]))
# Out:
# [[-0.04126715, 0.06610896, -0.17821075, -0.01661926, 0.021293543, -0.026347106, -0.011972777, 0.017044395, -0.0102463225, -0.031984292, 0.05074038, -0.019021079, 0.0455955, -0.008334159, 0.012143475, 0.02095224, -0.040152553, -0.062107455, -0.03076057, -0.0075599533, -0.016777014, -0.029407192, -0.0114680985, 0.032442577, 0.08969293, 0.053600416, -0.027184274, 0.019477315, -0.007775929, 0.058883317, 0.07545687, -0.028517261, 0.021130083, 0.010203293, 0.043243945, 0.033842947, -0.005341481, 0.011523034, -0.005162562, 0.0016909849, 0.041827112, 0.009604188, 0.0319201, -0.005478678, 0.048808046, -0.07658871, 0.020515414, 0.044647966, 0.050691955, -0.07108174, -0.020428965, -0.02877028, -0.026621645, 0.008569866, 0.06535682, -0.019215789, -0.018015279, -0.011391155, 0.007945708, 0.016225822, 0.08523788, 0.03018747, 0.0013972234, 0.06267669, 0.019710233, 0.05233251, -0.012239113, 0.07123865, -0.008244852, -0.012078033, 0.057228368, 0.0058071995, -0.0028748459, 0.012906481, -0.019603822, 0.019969579, -0.0016487382, -0.075757906, -0.010027052, 0.0013066491, 0.0123515325, -0.027487759, 0.0847851, -0.054994635, 0.05856583, -0.027065625, 0.023044728, -0.023822993, -0.0053224424, 0.078602746, -0.010046806, 0.035492484, -0.018196503, 0.034648612, -0.034684893, -0.0010942846, 0.015430942, 0.008145163, -0.09678323, 0.030529391, -0.050625302, -0.027234767, -0.05010342, 0.004582771, 0.07360055, -0.0062386985, -0.024721928, -0.027243465, -0.015014182, 0.018931676, 0.010712331, 0.023638222, -0.0078704385, -0.037504476, 0.0095721865, 0.018942988, 0.07712377, -0.0704372, 0.07470216, -0.008237631, -0.0050022216, -0.00055506424, 0.008611233, -0.03337597, 0.002629069, -0.005636847, -0.04046315, -0.018455097, -0.035580534, -0.058507662, -0.013595494, 0.00013116217, -0.038666196, -0.004982778, 0.028738933, 0.022913817, -0.028119847, -0.05798944, -0.0014136882, 0.019626113, 0.01209573, -0.015908152, -0.003912564, 0.024061106, 0.00674939, -0.039868176, 0.043374177, 0.014247019, 0.0045425217, -0.009955458, 0.010968274, 0.007196491, -0.010856719, 0.05773648, -0.010326974, -0.04316352, -0.03578282, -0.046836, 0.06311142, 0.02110166, 0.016315514, 0.025499448, -0.0703711, 0.028625885, 0.034607537, -0.06025681, 0.046756223, 0.049184274, 0.055420447, 0.0065301685, -0.10276397, -0.060136277, 0.0060601267, 0.002776724, 0.0014164643, -0.07003395, -0.0059394445, -0.020919649, 0.030454438, 0.01766673, 0.062282816, -0.03183638, -0.0021907585, 0.031443905, -0.04102279, 0.007103667, -0.031679194, 0.006667624, -0.019125711, -0.017323619, 0.027281791, -0.014195322, -0.07521395, -0.003176007, -0.057310905, -0.013495928, 0.029608471, 0.010830743, 0.061070014, -0.046697382, -0.03251875, -0.007861183, -0.033067383, 0.04729191, 0.023096588, 0.053215645, -0.01902615, 0.034049816, -0.0007710099, 0.012128646, 0.061505806, 0.019092774, 0.018463286, 0.014957617, 0.01976847, 0.022301076, -0.021473242, -0.059331328, -0.006452154, 0.016203698, 0.06673757, 0.010519749, 0.03409543, -0.006758009, 0.04523075, -0.097259685, -0.04025365, 0.042523306, -0.0014722554, 0.050966363, -0.021285543, -0.034172885, 0.014507881, 0.025314847, -0.0014385115, 0.015964266, -0.011289005, 0.05758751, -0.0020198044, -0.02597847, -0.012354513, 0.0032247237, -0.032525335, -0.053485624, -0.06449348, 0.00034796714, -0.061062936, -0.035019442, -0.03406167, -0.026325718, 0.03153128, 0.051854186, 0.0017311098, -0.049954884, 0.021418868, 0.0151696745, 0.004533864, -0.018322991, 0.016997902, -0.02301543, 0.06840869, -0.04363364, 0.027768595, -0.04665183, 0.03879045, 0.03331324, -0.046101652, -0.0115729105, 0.0022620694, -0.06351224, -0.017115135, 0.052154448, -0.0044432073, 0.018461825, 0.002345974, 0.0017405483, 0.004293987, 0.029523386, -0.048001144, 0.033036392, -0.059393153, 0.010904546, -0.037072808, 0.016703414, 0.025934553, 0.022482086, 0.008168983, 0.0134011125, 0.051496424, 0.003962164, 0.06606006, 0.04380114, 0.017420487, 0.09367474, -0.057343457, -0.01031349, 0.0059721605, -0.00019280254, -0.049189158, 0 ...
# 768

# %% [markdown]
# As we can see the text is converted into a vector with a size 1*768

# %%
# Generate an embedding for a batch input
response = embed(model='nomic-embed-text', input=festival_talks)

# %%
# Access the embedding vectors
embedding = response['embeddings']

print(len(embedding), len(embedding[0]), len(embedding[0]))
# Out:
# 10 768 768

# %% [markdown]
# So we can see now that we have a list of 10 entries each with a vector with 768 entries

# %%
#pip install numpy

# %%
import numpy as np

vectors = np.array(embedding)

query = np.array(embed(model='nomic-embed-text', input='I am interested in talks about social working conditions')['embeddings'])

# Compute Euclidean distances
differences = vectors - query  # shape: (n_vectors, vector_dim)
distances = np.linalg.norm(differences, axis=1)

# Index of closest vector
closest_index = np.argmin(distances)

# Sorted indices by distance
sorted_indices = np.argsort(distances)

print("Closest vector index:", closest_index)
print("Distance:", distances[closest_index])
print("Sorted indices by distance:", sorted_indices)
# Out:
# Closest vector index: 3
# Distance: 0.9216376888352822
# Sorted indices by distance: [3 7 4 9 1 8 2 0 5 6]

# %%
festival_talks[closest_index]
# Out:
# '💼🚫 Post-Work: Imagining a Life Beyond Jobs — As automation reshapes labor, what comes next? UBI, digital nomadism, reputation economies — a candid discussion about freedom, purpose, and survival.'

# %%
# Sort festival_talks according to the sorted_indices
sorted_festival_talks = [festival_talks[i] for i in sorted_indices]

# Optionally print it
for num, talk in enumerate(sorted_festival_talks):
    print(num+1, talk)
    print()
# Out:
# 1 💼🚫 Post-Work: Imagining a Life Beyond Jobs — As automation reshapes labor, what comes next? UBI, digital nomadism, reputation economies — a candid discussion about freedom, purpose, and survival.
#
# 2 💻⚖️ Code as Culture: Programming the Future We Want — Code is not neutral — it shapes societies. This talk explores how developers are becoming the new lawmakers, and how we hold them accountable.
#
# 3 🪐 Planet B: Terraforming Ideas for Earth 2.0 — Science fiction meets climate urgency. This talk blends real research with wild speculation — from Mars domes to floating cities in the clouds of Venus.
#
# 4 🕰️🚀 Time Travelers Welcome: Building the Long Now — Futurists, historians, and deep-time thinkers gather to explore projects that think in centuries — from 10,000-year clocks to interstellar archives.
#
# 5 🧠 Neural Frontiers: The Brain-Computer Interface Revolution — From thought-controlled devices to memory enhancement, dive into the fast-evolving world of brain tech — and the ethical mazes it brings.
#
# 6 🕸️🛠️ The Wild Web: Reclaiming the Internet from Algorithms — Can we rebuild the web for people, not profit? Meet the rebels, hackers, and dreamers creating decentralized, community-first digital spaces.
#
# 7 🎨🤖 AI & the Soul of Art: Who Really Owns Creativity? — Artists, coders, and philosophers debate the rise of generative art. Can machines make meaning? And where does human intuition still reign supreme?
#
# 8 🌿 The Next Nature: Designing with the Future in Mind — Explore how biomimicry, regenerative design, and synthetic biology are reshaping architecture, materials, and cities. Where does design end and nature begin?
#
# 9 🕶️🌐 Reality is Optional: The Rise of Immersive Worlds — VR, AR, XR — and whatever’s next. What happens when our digital spaces feel more real than reality itself? And who gets to write the rules?
#
# 10 🧬⏳ The Ethics of Immortality: Living Forever in a Mortal World — Cryonics, gene editing, mind uploading — tech is chasing eternal life. But what would it mean for love, loss, and the human condition?

# %% [markdown]
# So for real retrieval we have to set a retrieval count of how many documents we want to retrieve e.g. **k=3**

# %%
retrieved_festival_talks = sorted_festival_talks[:4]

# %% [markdown]
# Let's now make our final call

# %%
retrieved_content = '\n\n'.join(retrieved_festival_talks)

chat_response = chat(model='gemma3:1b', messages=[
    {
    'role': 'user',
    'content': 'User Question:\nI am interested in talks about social working conditions\n\n' + 'Answer the user question on festival talks as best as you can based on the retrieved festival talks\n\nRetrieved content:\n\n' + retrieved_content,
    },
])

display(Markdown(chat_response.message.content))
# Out:
# Okay, based on the retrieved talks, here's a breakdown of potential social work talk topics, focusing on the themes of conditions and the future:
#
# **Core Themes & Potential Talk Topics:**
#
# 1. **Post-Work & Automation:** This is the most prominent theme and suggests a lot of potential for social work conversations.  Here are some specific ideas:
#     * **The Impact of Automation on Social Services:** How will job displacement affect vulnerable populations (e.g., elderly, disabled, low-income)?
#     * **Universal Basic Income (UBI) and its Social Worker Role:**  Discussing how UBI could reshape social services – providing a safety net, facilitating retraining, or redefining the purpose of social work.
#     * **Digital Nomadism & Social Support:** How can social workers support individuals navigating the uncertainties of remote work and the lack of traditional employment?
#     * **Reputation Economies & Social Work:** Exploring how social workers need to understand and address the challenges of reputation in a digital world.
#
# 2. **Code as Culture & Social Impact:** This talk highlights the growing significance of technology and its influence on society, which directly relates to social work.
#     * **Developers & Accountability:** Analyzing the responsibility of software developers – how can we ensure ethical development and prevent harm?
#     * **Algorithmic Bias & Social Justice:**  Discussing how biases in algorithms can perpetuate inequality and how social workers can address these issues.
#     * **Digital Literacy & Social Isolation:** How can social workers address issues related to digital exclusion and online harm?
#
# 3. **Terraforming Ideas & Climate Crisis:**  The "Planet B" talk points towards the urgency of addressing climate change, and it suggests a conversation about social responsibility in the face of environmental challenges.
#     * **Social Justice & Climate Resilience:** How can social workers contribute to building more resilient communities facing climate change impacts (e.g., displacement, food insecurity)?
#     * **Community-Based Climate Action:** Discussing the role of social workers in facilitating community-led initiatives to mitigate climate change.
#     * **The Future of Social Services in a Changing Climate:** How will social services adapt to the unavoidable consequences of climate change?
#
# 4. **Long Now & Future Thinking:**  This talk offers a unique perspective on the longer-term challenges facing humanity.
#     * **The Value of Long-Term Planning:** How can social workers apply the principles of the Long Now – thinking beyond immediate problems – to address systemic issues?
#     * **Designing for Resilience & Sustainability:** Exploring how social work can contribute to designing systems that are resilient to future shocks (economic, social, environmental).
#
#
# **Overall, the talks would likely revolve around these key areas:**
#
# *   **Systemic Change:**  Moving beyond individual support to address the root causes of social problems.
# *   **Technological Responsibility:**  Understanding and mitigating the potential negative consequences of technological advancements.
# *   **Social Justice & Equity:** Ensuring that vulnerable populations are supported and empowered.
# *   **Adaptability & Resilience:** Preparing for a rapidly changing world and building communities that can withstand disruption.
#
# To help me refine the suggestions further, could you tell me:
#
# *   **What type of social work are you most interested in?** (e.g., child welfare, mental health, poverty alleviation, etc.)
# *   **Are there any specific aspects of social work you'd like to focus on?**

# %% [markdown]
# ## Conclusion
#
# Okay we saw that the whole idea of retrieval augmented generation is quite simple and depends on augmenting the LLM with extra context in the prompt. The context could also be retrieved if there is a lot of content and we are not able to just stick everything in the prompt. Now we already have a nice RAG chatbot coded by hand!!

# %% [markdown]
# ### Change the search function to cosine similarity:

# %%
# change Euklidean distance to cosine similarity

import numpy as np

vectors = np.array(embedding)

query = np.array(embed(model='nomic-embed-text', input='I am interested in talks about social working conditions')['embeddings'])

# # Compute Euclidean distances
# differences = vectors - query  # shape: (n_vectors, vector_dim)
# distances = np.linalg.norm(differences, axis=1)

# # Index of closest vector
# closest_index = np.argmin(distances)

# # Sorted indices by distance
# sorted_indices = np.argsort(distances)

# Compute cosine similarity
# cosine similarity = (A . B) / (||A|| * ||B||)
query_norm = np.linalg.norm(query)
vectors_norm = np.linalg.norm(vectors, axis=1)

# Dot product
dot_products = np.dot(vectors, query.flatten())

# Cosine similarity (higher = more similar)
cosine_similarity = dot_products / (vectors_norm * query_norm)

# For cosine similarity, higher values mean more similar
closest_index = np.argmax(cosine_similarity)
sorted_indices = np.argsort(cosine_similarity)[::-1]  # Sort descending

print("Closest vector index:", closest_index)
print("Cosine similarity:", cosine_similarity[closest_index])
print("Sorted indices by similarity:", sorted_indices)
# Out:
# Closest vector index: 3
# Cosine similarity: 0.5752922709950583
# Sorted indices by similarity: [3 7 4 9 1 8 2 0 5 6]

# %% [markdown]
# The output with Euclidean distances was:
#
# ```
# Closest vector index: 3
# Distance: 0.9216376888352822
# Sorted indices by distance: [3 7 4 9 1 8 2 0 5 6]
# ```
#
# So with cosine similarity, the resulting order was exactly the same!
